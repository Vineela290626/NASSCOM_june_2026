# %%
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

# --- Global Data for the Exercise (Simulated Data) ---
# We'll imagine this is sensor data from various devices.
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0),   # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000)        # Lux
}
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------

# %%
# --- Task 1: Python Fundamentals, Lists, Tuples, Sets, Dictionaries, Indexing & Slicing ---
print("\n--- Task 1: Data Generation and Basic Structures ---")
# 1.1 Generate a list of 100 simulated sensor readings.
#    Each reading should be a tuple: (timestamp_str, device_id, device_type, location, value).
#    - timestamp_str: Format as 'YYYY-MM-DD HH:MM:SS'
#    - device_id: A unique ID for each reading (e.g., 'DEV001', 'DEV002', etc., up to 100 unique IDs).
#    - device_type: Randomly chosen from DEVICE_TYPES.
#    - location: Randomly chosen from LOCATIONS.
#    - value: Random float within READING_RANGES for its device_type (round to 2 decimal places).
# Store these in a list called 'raw_sensor_data'.

# %%
raw_sensor_data = []

for i in range(0, 100):
    # Generate timestamp
    start_date = datetime.datetime(2023, 1, 1, 0, 0, 0)
    end_date = datetime.datetime(2023, 1, 31, 23, 59, 59)
    random_timestamp = start_date + (end_date - start_date) * random.random()
    timestamp_str = random_timestamp.strftime('%Y-%m-%d %H:%M:%S')

    # Generate unique device_id
    device_id = f'DEV{i:03d}'

    # Randomly choose device_type and location
    device_type = random.choice(DEVICE_TYPES)
    location = random.choice(LOCATIONS)

    # Generate value based on device_type reading range
    min_val, max_val = READING_RANGES[device_type]
    value = round(random.uniform(min_val, max_val), 2)

    raw_sensor_data.append((timestamp_str, device_id, device_type, location, value))

print(f"Generated {len(raw_sensor_data)} sensor readings.")
# Display the first 5 readings to verify
for j in range(5):
    print(raw_sensor_data[j])
# Out:
# Generated 100 sensor readings.
# ('2023-01-17 22:31:38', 'DEV000', 'Pressure_Sensor', 'Lab1', 1016.8)
# ('2023-01-20 13:50:25', 'DEV001', 'Light_Sensor', 'Lab1', 690.74)
# ('2023-01-12 14:10:25', 'DEV002', 'Light_Sensor', 'OfficeB', 455.77)
# ('2023-01-21 07:41:20', 'DEV003', 'Light_Sensor', 'Lab1', 997.31)
# ('2023-01-14 17:16:13', 'DEV004', 'Pressure_Sensor', 'Lab1', 1016.43)

# %%
temperature_readings = []
for timestamp_str, device_id, device_type, location, value in raw_sensor_data:
    if device_type == 'Temperature_Sensor':
        temperature_readings.append({
            'timestamp': timestamp_str,
            'device_id': device_id,
            'location': location,
            'temperature_celsius': value
        })

print(f"Generated {len(temperature_readings)} temperature readings.")
# Display the first 5 temperature readings to verify
for i in range(min(5, len(temperature_readings))):
    print(temperature_readings[i])
# Out:
# Generated 26 temperature readings.
# {'timestamp': '2023-01-12 16:49:03', 'device_id': 'DEV007', 'location': 'Lab1', 'temperature_celsius': 26.63}
# {'timestamp': '2023-01-24 03:47:57', 'device_id': 'DEV013', 'location': 'Lab1', 'temperature_celsius': 25.57}
# {'timestamp': '2023-01-11 22:28:42', 'device_id': 'DEV020', 'location': 'Lab1', 'temperature_celsius': 25.34}
# {'timestamp': '2023-01-06 10:17:51', 'device_id': 'DEV021', 'location': 'OfficeB', 'temperature_celsius': 28.53}
# {'timestamp': '2023-01-15 09:48:32', 'device_id': 'DEV025', 'location': 'OfficeA', 'temperature_celsius': 23.86}

# %%
unique_locations = set()
for _, _, _, location, _ in raw_sensor_data:
    unique_locations.add(location)

print(f"Unique locations: {unique_locations}")
# Out:
# Unique locations: {'Lab1', 'Warehouse', 'OfficeA', 'OfficeB', 'Lab2'}

# %%
device_stats = {}

# Initialize device_stats with sensible large/small values
for device_type in DEVICE_TYPES:
    device_stats[device_type] = (float('inf'), float('-inf')) # (min_value, max_value)

for _, _, device_type, _, value in raw_sensor_data:
    current_min, current_max = device_stats[device_type]
    device_stats[device_type] = (min(current_min, value), max(current_max, value))

print("Device statistics:")
for device_type, (min_val, max_val) in device_stats.items():
    print(f"  {device_type}: Min={min_val:.2f}, Max={max_val:.2f}")
# Out:
# Device statistics:
#   Temperature_Sensor: Min=19.01, Max=29.26
#   Humidity_Sensor: Min=30.81, Max=79.26
#   Pressure_Sensor: Min=980.26, Max=1021.26
#   Light_Sensor: Min=310.15, Max=997.31

# %%
sliced_readings_1 = raw_sensor_data[9:20+1]
sliced_readings_2 = raw_sensor_data[::5]

print("Sliced Readings 1 (10th to 20th inclusive):")
for reading in sliced_readings_1:
    print(reading)

print("\nSliced Readings 2 (every 5th reading):")
for reading in sliced_readings_2:
    print(reading)

sample_string = "Python Programming is Fun!"
substring_1 = sample_string[7:18]
substring_2 = sample_string[5::-1]

print(f"\nSample String: '{sample_string}'")
print(f"Substring 1 ('Programming'): '{substring_1}'")
print(f"Substring 2 ('nohtyP'): '{substring_2}'")

fifth_reading = raw_sensor_data[4]
fifth_reading_device_type = fifth_reading[2]
device_type_suffix = fifth_reading_device_type[-6:]

print(f"\nFifth Reading: {fifth_reading}")
print(f"Fifth Reading Device Type: '{fifth_reading_device_type}'")
print(f"Device Type Suffix: '{device_type_suffix}'")
# Out:
# Sliced Readings 1 (10th to 20th inclusive):
# ('2023-01-15 09:37:54', 'DEV009', 'Humidity_Sensor', 'Lab1', 45.12)
# ('2023-01-25 01:32:05', 'DEV010', 'Light_Sensor', 'Warehouse', 355.39)
# ('2023-01-20 08:12:50', 'DEV011', 'Humidity_Sensor', 'Warehouse', 58.02)
# ('2023-01-02 15:21:05', 'DEV012', 'Pressure_Sensor', 'OfficeA', 1007.82)
# ('2023-01-24 03:47:57', 'DEV013', 'Temperature_Sensor', 'Lab1', 25.57)
# ('2023-01-05 16:10:46', 'DEV014', 'Light_Sensor', 'Warehouse', 638.73)
# ('2023-01-12 21:48:44', 'DEV015', 'Humidity_Sensor', 'Lab1', 50.39)
# ('2023-01-23 15:39:05', 'DEV016', 'Pressure_Sensor', 'Lab1', 1004.09)
# ('2023-01-10 06:23:39', 'DEV017', 'Pressure_Sensor', 'Lab1', 980.26)
# ('2023-01-24 14:57:01', 'DEV018', 'Humidity_Sensor', 'Warehouse', 35.95)
# ('2023-01-24 21:18:52', 'DEV019', 'Light_Sensor', 'Warehouse', 979.12)
# ('2023-01-11 22:28:42', 'DEV020', 'Temperature_Sensor', 'Lab1', 25.34)
#
# Sliced Readings 2 (every 5th reading):
# ('2023-01-17 22:31:38', 'DEV000', 'Pressure_Sensor', 'Lab1', 1016.8)
# ('2023-01-10 02:02:22', 'DEV005', 'Pressure_Sensor', 'OfficeB', 982.11)
# ('2023-01-25 01:32:05', 'DEV010', 'Light_Sensor', 'Warehouse', 355.39)
# ('2023-01-12 21:48:44', 'DEV015', 'Humidity_Sensor', 'Lab1', 50.39)
# ('2023-01-11 22:28:42', 'DEV020', 'Temperature_Sensor', 'Lab1', 25.34)
# ('2023-01-15 09:48:32', 'DEV025', 'Temperature_Sensor', 'OfficeA', 23.86)
# ('2023-01-06 23:12:17', 'DEV030', 'Temperature_Sensor', 'OfficeA', 20.14)
# ('2023-01-28 07:17:08', 'DEV035', 'Humidity_Sensor', 'Lab1', 67.72)
# ('2023-01-01 23:58:39', 'DEV040', 'Light_Sensor', 'Lab1', 821.27)
# ('2023-01-29 16:19:15', 'DEV045', 'Humidity_Sensor', 'OfficeA', 32.37)
# ('2023-01-13 18:25:55', 'DEV050', 'Temperature_Sensor', 'Lab1', 27.09)
# ('2023-01-16 11:52:52', 'DEV055', 'Humidity_Sensor', 'Lab1', 50.28)
# ('2023-01-18 05:29:22', 'DEV060', 'Pressure_Sensor', 'Lab1', 1011.07)
# ('2023-01-05 14:48:16', 'DEV065', 'Humidity_Sensor', 'Lab1', 79.26)
# ('2023-01-28 10:46:33', 'DEV070', 'Pressure_Sensor', 'Lab2', 989.3)
# ('2023-01-17 04:19:59', 'DEV075', 'Temperature_Sensor', 'OfficeB', 25.11)
# ('2023-01-17 04:55:52', 'DEV080', 'Temperature_Sensor', 'Lab2', 24.19)
# ('2023-01-18 00:57:46', 'DEV085', 'Temperature_Sensor', 'Lab2', 19.65)
# ('2023-01-25 00:00:01', 'DEV090', 'Pressure_Sensor', 'Lab2', 1015.09)
# ('2023-01-29 09:00:05', 'DEV095', 'Pressure_Sensor', 'Warehouse', 1014.44)
#
# Sample String: 'Python Programming is Fun!'
# Substring 1 ('Programming'): 'Programming'
# Substring 2 ('nohtyP'): 'nohtyP'
#
# Fifth Reading: ('2023-01-14 17:16:13', 'DEV004', 'Pressure_Sensor', 'Lab1', 1016.43)
# Fifth Reading Device Type: 'Pressure_Sensor'
# Device Type Suffix: 'Sensor'

# %%
print("\n--- Task 2: Function Definitions and Usage ---")
def get_readings_by_location(readings_list, target_location):
  return [reading for reading in readings_list if reading[3] == target_location]
def calculate_average_temperature(temp_data_list):
     if not temp_data_list:
        return 0.0
     total_temp = sum(item['temperature_celsius'] for item in temp_data_list)
     return total_temp / len(temp_data_list)
def generate_report_line(reading_dict):
    timestamp = reading_dict.get('timestamp', 'N/A')
    device_id = reading_dict.get('device_id', 'N/A')
    location = reading_dict.get('location', 'N/A')
    temperature_celsius = reading_dict.get('temperature_celsius', 'N/A')
    return f"[{timestamp}] Device {device_id} at {location}: {temperature_celsius}°C"
# Out:
# --- Task 2: Function Definitions and Usage ---

# %%
average_temp = calculate_average_temperature(temperature_readings)
print(f"\nAverage temperature from 'temperature_readings': {average_temp:.2f}°C")
# Out:
# Average temperature from 'temperature_readings': 24.21°C

# %%
if temperature_readings:
    sample_report_line = generate_report_line(temperature_readings[0])
    print(f"\nSample report line: {sample_report_line}")
# Out:
# Sample report line: [2023-01-12 16:49:03] Device DEV007 at Lab1: 26.63°C

# %%
random_values = [random.randint(100, 200) for _ in range(5)]
print(f"\nGenerated random values: {random_values}")
# Out:
# Generated random values: [106, 146, 170, 134, 106]

# %%
read_report_lines = []
try:
    with open(report_filename, 'r') as f:
        read_report_lines = f.readlines()
    print(f"\nRead {len(read_report_lines)} lines from '{report_filename}'.")
    print("First 3 lines of the read report:")
    for i in range(min(3, len(read_report_lines))):
        print(read_report_lines[i].strip())
except FileNotFoundError:
    print(f"\nError: File '{report_filename}' not found.")
except IOError as e:
    print(f"\nError reading file '{report_filename}': {e}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2071/4250737704.py in <cell line: 0>()
#       1 read_report_lines = []
#       2 try:
# ----> 3     with open(report_filename, 'r') as f:
#       4         read_report_lines = f.readlines()
#       5     print(f"\nRead {len(read_report_lines)} lines from '{report_filename}'.")
#
# NameError: name 'report_filename' is not defined

# %%
raw_sensor_data = []

for i in range(0, 100):
    # Generate timestamp
    start_date = datetime.datetime(2023, 1, 1, 0, 0, 0)
    end_date = datetime.datetime(2023, 1, 31, 23, 59, 59)
    random_timestamp = start_date + (end_date - start_date) * random.random()
    timestamp_str = random_timestamp.strftime('%Y-%m-%d %H:%M:%S')

    # Generate unique device_id
    device_id = f'DEV{i:03d}'

    # Randomly choose device_type and location
    device_type = random.choice(DEVICE_TYPES)
    location = random.choice(LOCATIONS)

    # Generate value based on device_type reading range
    min_val, max_val = READING_RANGES[device_type]
    value = round(random.uniform(min_val, max_val), 2)

    raw_sensor_data.append((timestamp_str, device_id, device_type, location, value))

print(f"Generated {len(raw_sensor_data)} sensor readings.")
# Display the first 5 readings to verify
for j in range(min(5, len(raw_sensor_data))):
    print(raw_sensor_data[j])

# 1.2 From 'raw_sensor_data', create a list named 'temperature_readings' containing only the readings
#     where 'device_type' is 'Temperature_Sensor'.
#     Each item in 'temperature_readings' should be a dictionary with keys:
#     'timestamp', 'device_id', 'location', 'temperature_celsius'.
temperature_readings = []
for timestamp_str, device_id, device_type, location, value in raw_sensor_data:
    if device_type == 'Temperature_Sensor':
        temperature_readings.append({
            'timestamp': timestamp_str,
            'device_id': device_id,
            'location': location,
            'temperature_celsius': value
        })

print(f"Generated {len(temperature_readings)} temperature readings.")
# Display the first 5 temperature readings to verify
for i in range(min(5, len(temperature_readings))):
    print(temperature_readings[i])

# 1.3 Create a set named 'unique_locations' containing all unique locations from 'raw_sensor_data'.
unique_locations = set()
for _, _, _, location, _ in raw_sensor_data:
    unique_locations.add(location)

print(f"Unique locations: {unique_locations}")

# 1.4 Create a dictionary named 'device_stats' where keys are 'device_type' and values are
#     a tuple: (min_value, max_value) observed for that device type across all readings.
#     Initialize with sensible large/small values.
device_stats = {}

# Initialize device_stats with sensible large/small values
for device_type in DEVICE_TYPES:
    device_stats[device_type] = (float('inf'), float('-inf')) # (min_value, max_value)

for _, _, device_type, _, value in raw_sensor_data:
    current_min, current_max = device_stats[device_type]
    device_stats[device_type] = (min(current_min, value), max(current_max, value))

print("Device statistics:")
for device_type, (min_val, max_val) in device_stats.items():
    print(f"  {device_type}: Min={min_val:.2f}, Max={max_val:.2f}")

# 2.2 Write a function `calculate_average_temperature(temp_data_list)`
#     that takes the 'temperature_readings' list (list of dictionaries).
#     It should calculate and return the average temperature. Return 0.0 if the list is empty.
average_temp = calculate_average_temperature(temperature_readings)
print(f"\nAverage temperature from 'temperature_readings': {average_temp:.2f}°C")

# 2.3 Write a function `generate_report_line(reading_dict)`
#     that takes a single temperature reading dictionary.
#     It should return a formatted string like:
#     "[{timestamp}] Device {device_id} at {location}: {temperature_celsius}°C"
if temperature_readings:
    sample_report_line = generate_report_line(temperature_readings[0])
    print(f"\nSample report line: {sample_report_line}")

# 3.3 Generate a list of 5 random integer values between 100 and 200 (inclusive)
#     using the `random` module. Store it in 'random_values'.
random_values = [random.randint(100, 200) for _ in range(5)]
print(f"\nGenerated random values: {random_values}")

# Define reports_dir and report_filename for file operations
reports_dir = 'sensor_reports'
report_filename = os.path.join(reports_dir, 'temperature_report.txt')

# Ensure the directory exists before writing
if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"Directory '{reports_dir}' created.")

# 4.1 Write all 'temperature_readings' to a file named 'sensor_reports/temperature_report.txt'.
#     Each line in the file should be generated using the `generate_report_line` function.
try:
    with open(report_filename, 'w') as f:
        for reading_dict in temperature_readings:
            line = generate_report_line(reading_dict)
            f.write(line + '\n')
    print(f"\nTemperature report written to '{report_filename}'.")
except IOError as e:
    print(f"\nError writing file '{report_filename}': {e}")

# 4.2 Read the content of 'sensor_reports/temperature_report.txt' back into a list of strings
#     named 'read_report_lines'. Print the first 3 lines.
read_report_lines = []
try:
    with open(report_filename, 'r') as f:
        read_report_lines = f.readlines()
    print(f"\nRead {len(read_report_lines)} lines from '{report_filename}'.")
    print("First 3 lines of the read report:")
    for i in range(min(3, len(read_report_lines))):
        print(read_report_lines[i].strip())
except FileNotFoundError:
    print(f"\nError: File '{report_filename}' not found.")
except IOError as e:
    print(f"\nError reading file '{report_filename}': {e}")
# Out:
# Generated 100 sensor readings.
# ('2023-01-08 23:41:28', 'DEV000', 'Humidity_Sensor', 'Lab1', 54.06)
# ('2023-01-18 02:35:17', 'DEV001', 'Light_Sensor', 'Warehouse', 350.13)
# ('2023-01-02 14:33:46', 'DEV002', 'Pressure_Sensor', 'OfficeB', 995.7)
# ('2023-01-03 11:36:19', 'DEV003', 'Pressure_Sensor', 'OfficeA', 987.66)
# ('2023-01-26 10:10:01', 'DEV004', 'Pressure_Sensor', 'OfficeB', 988.82)
# Generated 33 temperature readings.
# {'timestamp': '2023-01-10 01:20:38', 'device_id': 'DEV005', 'location': 'Warehouse', 'temperature_celsius': 20.64}
# {'timestamp': '2023-01-25 21:58:59', 'device_id': 'DEV007', 'location': 'OfficeA', 'temperature_celsius': 28.0}
# {'timestamp': '2023-01-02 20:26:53', 'device_id': 'DEV009', 'location': 'OfficeB', 'temperature_celsius': 21.98}
# {'timestamp': '2023-01-19 16:36:22', 'device_id': 'DEV010', 'location': 'OfficeA', 'temperature_celsius': 23.62}
# {'timestamp': '2023-01-21 19:59:54', 'device_id': 'DEV017', 'location': 'OfficeA', 'temperature_celsius': 28.26}
# Unique locations: {'Lab1', 'Warehouse', 'OfficeA', 'OfficeB', 'Lab2'}
# Device statistics:
#   Temperature_Sensor: Min=18.38, Max=29.78
#   Humidity_Sensor: Min=35.99, Max=71.64
#   Pressure_Sensor: Min=984.19, Max=1028.29
#   Light_Sensor: Min=149.41, Max=949.69
#
# Average temperature from 'temperature_readings': 24.02°C
#
# Sample report line: [2023-01-10 01:20:38] Device DEV005 at Warehouse: 20.64°C
#
# Generated random values: [104, 166, 120, 183, 135]
# Directory 'sensor_reports' created.
#
# Temperature report written to 'sensor_reports/temperature_report.txt'.
#
# Read 33 lines from 'sensor_reports/temperature_report.txt'.
# First 3 lines of the read report:
# [2023-01-10 01:20:38] Device DEV005 at Warehouse: 20.64°C
# [2023-01-25 21:58:59] Device DEV007 at OfficeA: 28.0°C
# [2023-01-02 20:26:53] Device DEV009 at OfficeB: 21.98°C

# %%
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

# --- Global Data for the Exercise (Simulated Data) ---
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0),
    'Humidity_Sensor': (30.0, 80.0),
    'Pressure_Sensor': (980.0, 1030.0),
    'Light_Sensor': (100, 1000)
}

# --- Task 1: Python Fundamentals, Lists, Tuples, Sets, Dictionaries, Indexing & Slicing ---
print("\n--- Task 1: Data Generation and Basic Structures ---")

# Task 1.1
raw_sensor_data = []
start_time = datetime.datetime.now()

for i in range(100):
    device_type = random.choice(DEVICE_TYPES)
    location = random.choice(LOCATIONS)

    min_val, max_val = READING_RANGES[device_type]
    value = round(random.uniform(min_val, max_val), 2)

    timestamp = (start_time + datetime.timedelta(minutes=i)).strftime('%Y-%m-%d %H:%M:%S')
    device_id = f"DEV{i+1:03d}"

    raw_sensor_data.append((timestamp, device_id, device_type, location, value))

# Task 1.2
temperature_readings = []

for reading in raw_sensor_data:
    if reading[2] == 'Temperature_Sensor':
        temperature_readings.append({
            'timestamp': reading[0],
            'device_id': reading[1],
            'location': reading[3],
            'temperature_celsius': reading[4]
        })

# Task 1.3
unique_locations = {reading[3] for reading in raw_sensor_data}

# Task 1.4
device_stats = {}

for device in DEVICE_TYPES:
    device_stats[device] = (float('inf'), float('-inf'))

for reading in raw_sensor_data:
    device_type = reading[2]
    value = reading[4]

    current_min, current_max = device_stats[device_type]

    device_stats[device_type] = (
        min(current_min, value),
        max(current_max, value)
    )

# Task 1.5
print("\n--- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---")

sample_string = "PythonProgrammingIsFun"

# Task 1.5.1
sliced_readings_1 = raw_sensor_data[9:20]
sliced_readings_2 = raw_sensor_data[::5]

# Task 1.5.2
substring_1 = sample_string[6:17]
substring_2 = sample_string[5::-1]

# Task 1.5.3
fifth_reading_device_type = raw_sensor_data[4][2]
device_type_suffix = fifth_reading_device_type[-6:]

# --- Task 2: Writing and Using Functions in Python ---
print("\n--- Task 2: Function Definitions and Usage ---")

# Task 2.1
def get_readings_by_location(readings_list, target_location):
    return [reading for reading in readings_list if reading[3] == target_location]

# Task 2.2
def calculate_average_temperature(temp_data_list):
    if not temp_data_list:
        return 0.0

    total = sum(reading['temperature_celsius'] for reading in temp_data_list)
    return total / len(temp_data_list)

# Task 2.3
def generate_report_line(reading_dict):
    return (
        f"[{reading_dict['timestamp']}] "
        f"Device {reading_dict['device_id']} "
        f"at {reading_dict['location']}: "
        f"{reading_dict['temperature_celsius']}°C"
    )

# Sample Function Calls
lab1_readings = get_readings_by_location(raw_sensor_data, "Lab1")
avg_temp = calculate_average_temperature(temperature_readings)

print(f"\nUnique Locations: {unique_locations}")
print(f"Average Temperature: {avg_temp:.2f}°C")

# --- Task 3: Working with Core Python Libraries ---
print("\n--- Task 3: Core Library Usage ---")

# Task 3.1
reports_dir = 'sensor_reports'

if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"\nDirectory '{reports_dir}' created.")
else:
    print(f"\nDirectory '{reports_dir}' already exists.")

# Task 3.2
if len(raw_sensor_data) > 1:
    first_timestamp_str = raw_sensor_data[0][0]
    last_timestamp_str = raw_sensor_data[-1][0]

    date_format = '%Y-%m-%d %H:%M:%S'

    first_dt = datetime.datetime.strptime(first_timestamp_str, date_format)
    last_dt = datetime.datetime.strptime(last_timestamp_str, date_format)

    duration = last_dt - first_dt

    days = duration.days
    seconds = duration.total_seconds()
    hours = int(seconds // 3600) % 24
    minutes = int((seconds % 3600) // 60)

    print(f"\nDuration of data collection: {days} days, {hours} hours, {minutes} minutes.")
else:
    print("\nNot enough data to calculate duration.")

# Task 3.3
random_values = [random.randint(100, 200) for _ in range(5)]

print("\nRandom Values:", random_values)

# --- Task 4: File Handling in Python ---
print("\n--- Task 4: File I/O ---")

# Task 4.1
report_filename = os.path.join(reports_dir, 'temperature_report.txt')

try:
    with open(report_filename, 'w') as f:
        for reading_dict in temperature_readings:
            line = generate_report_line(reading_dict)
            f.write(line + '\n')

    print(f"\nTemperature report written to '{report_filename}'.")

except IOError as e:
    print(f"\nError writing file '{report_filename}': {e}")

# Task 4.2
read_report_lines = []

try:
    with open(report_filename, 'r') as f:
        read_report_lines = f.readlines()

    print("\nFirst 3 lines of the report:")

    for line in read_report_lines[:3]:
        print(line.strip())

except IOError as e:
    print(f"\nError reading file '{report_filename}': {e}")

print("\n--- Additional Outputs ---")
print("First Temperature Reading:")
if temperature_readings:
    print(generate_report_line(temperature_readings[0]))

print("\nDevice Statistics:")
for device, stats in device_stats.items():
    print(f"{device}: Min={stats[0]}, Max={stats[1]}")

print("\n--- Exercise Complete! ---")
print("Great job completing the intermediate Python exercise.")
print("Review your code and outputs to ensure correctness and understanding of all concepts.")
print("Consider adding more complex scenarios or user inputs for further practice.")
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------
#
# --- Task 1: Data Generation and Basic Structures ---
#
# --- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---
#
# --- Task 2: Function Definitions and Usage ---
#
# Unique Locations: {'Lab1', 'Warehouse', 'OfficeA', 'OfficeB', 'Lab2'}
# Average Temperature: 23.35°C
#
# --- Task 3: Core Library Usage ---
#
# Directory 'sensor_reports' already exists.
#
# Duration of data collection: 0 days, 1 hours, 39 minutes.
#
# Random Values: [182, 151, 117, 179, 185]
#
# --- Task 4: File I/O ---
#
# Temperature report written to 'sensor_reports/temperature_report.txt'.
#
# First 3 lines of the report:
# [2026-06-10 09:17:03] Device DEV010 at Lab2: 27.93°C
# [2026-06-10 09:21:03] Device DEV014 at OfficeB: 22.85°C
# [2026-06-10 09:25:03] Device DEV018 at OfficeA: 23.88°C
#
# --- Additional Outputs ---
# First Temperature Reading:
# [2026-06-10 09:17:03] Device DEV010 at Lab2: 27.93°C
#
# Device Statistics:
# Temperature_Sensor: Min=18.49, Max=28.64
# Humidity_Sensor: Min=30.22, Max=79.06
# Pressure_Sensor: Min=983.46, Max=1029.28
# Light_Sensor: Min=102.92, Max=996.32
#
# --- Exercise Complete! ---
# Great job completing the intermediate Python exercise.
# Review your code and outputs to ensure correctness and understanding of all concepts.
# Consider adding more complex scenarios or user inputs for further practice.

# %%
# creating vectors & basic operations

import numpy as np
u = np.array([2,3])
v = np.array([4,1])
print("u + v = ", u + v)
print("3* u = ", 3* u)
# Out:
# u + v =  [6 4]
# 3* u =  [6 9]

# %%
# dot product

dot1= np.dot(u,v)
dot2= u @ v
cos_theta = np.dot(u , v)/(np.linalg.norm(u)*np.linalg.norm(v))
theta = np.arccos(cos_theta)
print(f"Angle: {np.degrees(theta):.1f}")
# Out:
# Angle: 42.3

# %%
#norms & cosine similarity
w = np.array([3, -4])
print("L1:", np.linalg.norm(w, 1))
print("L2:", np.linalg.norm(w, 2))
print("Linf:", np.linalg.norm(w,np.inf))

from sklearn.metrics.pairwise import cosine_similarity
a,b=np.array([[1,2,3]]), np.array([[2,4,6]])
print(cosine_similarity(a,b))
# Out:
# L1: 7.0
# L2: 5.0
# Linf: 4.0
# [[1.]]

# %% [markdown]
# # Exercise vector,dot,norms and cosine

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# [Math, Science, English]
student1 = np.array([85, 90, 80])
student2 = np.array([88, 92, 78])
student3 = np.array([60, 70, 95])

# %%
print("Student 1 L2 Norm:", np.linalg.norm(student1))
print("Student 2 L2 Norm:", np.linalg.norm(student2))
print("Student 3 L2 Norm:", np.linalg.norm(student3))
# Out:
# Student 1 L2 Norm: 147.39402972983675
# Student 2 L2 Norm: 149.30505684671232
# Student 3 L2 Norm: 132.38202294873727

# %%
print("S1 vs S2:",
      cosine_similarity([student1], [student2]))

print("S1 vs S3:",
      cosine_similarity([student1], [student3]))

print("S2 vs S3:",
      cosine_similarity([student2], [student3]))
# Out:
# S1 vs S2: [[0.99969673]]
# S1 vs S3: [[0.97374378]]
# S2 vs S3: [[0.96785754]]

# %% [markdown]
# # Exercise matrix operations in numpy

# %%
import numpy as np
A = np.array([[1, 3, 7], [2, 4, 6],[3 ,5 ,1]])
b= np.array([20,25,31])
x= np.linalg.solve(A,b)
print("Prices:")
print("Product A:")
print(x[0])
print("Product B:")
print(x[1])
print("Product C:")
print(x[2])

print(" check A @ x :" , A @ x)
# Out:
# Prices:
# Product A:
# -3.749999999999998
# Product B:
# 8.499999999999998
# Product C:
# -0.24999999999999967
#  check A @ x : [20. 25. 31.]
